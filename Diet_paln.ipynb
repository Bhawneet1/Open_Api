# %%
# %pip install google-generativeai
# Out:
# ...
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# ...
#    ---------------------------------------- 0.0/175.4 kB ? eta -:--:--
#    --------------------- ------------------ 92.2/175.4 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 175.4/175.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.3 MB 3.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.3 MB 3.8 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.3 MB 3.7 MB/s eta 0:00:01
#    ------------------ --------------------- 0.6/1.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.9/1.3 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.1/1.3 MB 3.5 MB/s eta 0:00:01
# ...

# %%
import google.generativeai as genai

#set up api key
genai.configure(api_key="AIzaSyBT9ngbWp42FNRxxGuRCXPg8meQaJ6jaPs")

# %%
model = genai.GenerativeModel("gemini-pro")

# %%
response = model.generate_content("Explain black hole in simple terms")
print(response.text)
# Out:
# Imagine a giant vacuum cleaner in space that sucks up everything nearby, even light. That's a black hole!
#
# Black holes are created when massive stars die. When a star runs out of fuel, it collapses under its own gravity and becomes incredibly dense. This creates a region of spacetime where gravity is so strong that nothing, not even light, can escape.
#
# Inside a black hole, there is a point of infinite density called a singularity. It's like a tiny dot where all the mass of the black hole is concentrated.
#
# Black holes are invisible because light can't escape them. But we can see them by their effects on the objects around them. For example, a black hole can bend light from stars nearby, creating lensing effects. It can also pull in gas and dust, forming an accretion disk that glows with heat.
#
# Black holes are fascinating objects that are still being studied by scientists. They give us clues about the nature of gravity, spacetime, and the universe itself.
